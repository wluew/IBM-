# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **William Mujica, student**

# %% [markdown]
# *I am interested in data science because I have studied economics and I want to learn more about data and modeling data*

# %% [markdown]
# ### It will sume numbers

# %%
a=int(input('write a number'))
b=int(input('write another number'))
print("total sum",(a+b))
# Out:
# write a number5
# write another number7
# total sum 12

# %% [markdown]
# This is a line
# ****
#     another line
#     1. one line
#     2. two linw
#
# * bullet 1
# * bullet 2
# ![samu.jpg](attachment:samu.jpg)
